# %% [markdown]
# # Protein-defect interactions

# %%
import sys, os
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import importlib
import packing_defect.core.interactions as inter
importlib.reload(inter)
# Out:
# <module 'packing_defect.core.interactions' from '/mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/packing_defect/core/interactions.py'>

# %%
dirs = ["../results_defect/PLacyl", "../results_defect/TGacyl", "../results_defect/TGglyc"]
df = inter.run(dirs, cutoff=1.0, output_csv="results_defect/combined_interactions.csv")
df.head()
# Out:
# Processing PLacyl frame PLacyl_frame_0.gro
# Processing PLacyl frame PLacyl_frame_1.gro
# Processing PLacyl frame PLacyl_frame_10.gro
# Processing PLacyl frame PLacyl_frame_2.gro
# Processing PLacyl frame PLacyl_frame_3.gro
# Processing PLacyl frame PLacyl_frame_4.gro
# Processing PLacyl frame PLacyl_frame_5.gro
# Processing PLacyl frame PLacyl_frame_6.gro
# Processing PLacyl frame PLacyl_frame_7.gro
# Processing PLacyl frame PLacyl_frame_8.gro
# Processing PLacyl frame PLacyl_frame_9.gro
# Processing TGacyl frame TGacyl_frame_0.gro
# Processing TGacyl frame TGacyl_frame_1.gro
# Processing TGacyl frame TGacyl_frame_10.gro
# Processing TGacyl frame TGacyl_frame_2.gro
# Processing TGacyl frame TGacyl_frame_3.gro
# Processing TGacyl frame TGacyl_frame_4.gro
# Processing TGacyl frame TGacyl_frame_5.gro
# Processing TGacyl frame TGacyl_frame_6.gro
# Processing TGacyl frame TGacyl_frame_7.gro
# Processing TGacyl frame TGacyl_frame_8.gro
# Processing TGacyl frame TGacyl_frame_9.gro
# ...

# %%
df
# Out:
#       type  frame  resid resname
# 0   PLacyl      0     21     LEU
# 1   PLacyl      4     29     LEU
# 2   PLacyl      5     24     ILE
# 3   PLacyl      5     27     GLY
# 4   PLacyl      5     31     GLN
# 5   PLacyl      5     34     ASN
# 6   PLacyl      6      9     PHE
# 7   PLacyl      6     26     ILE
# 8   PLacyl      6     27     GLY
# 9   PLacyl      6     31     GLN
# 10  PLacyl      7      5     SER
# 11  PLacyl      8      4     LEU
# 12  PLacyl      8     21     LEU
# 13  PLacyl      8     22     ARG
# 14  PLacyl      8     26     ILE
# 15  PLacyl      8     28     VAL
# 16  PLacyl      9     21     LEU
# 17  PLacyl      9     25     VAL
# 18  PLacyl     10     28     VAL
# 19  PLacyl     10     32     LEU
# 20  PLacyl     10     36     LEU
# 21  TGacyl      5     24     ILE
# 22  TGacyl      6      7     CYS
# 23  TGacyl      6     34     ASN
# 24  TGacyl      7     29     LEU
# 25  TGacyl     10      4     LEU
# 26  TGglyc      5      3     GLU
