# %% [markdown]
# # Calculating defecets around radius of protein

# %% [markdown]
# This module identifies packing defects within a defined radius around the protein in each frame of your simulation. You can run the analysis in two ways:
#
# ---
#
# ### Option 1: Interactive Class-Based Usage (in Jupyter or Scripts)

# %%
import sys
import os
project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)
from packing_defect.core.analyzer_radius import RadiusDefectAnalyzer

# %%
analyzer = RadiusDefectAnalyzer(
    base_directory="../results",       # go up from notebooks/
    output_base_dir="../results_radius",
    lipid_types=["PLacyl", "TGacyl", "TGglyc"],
    frame_start=0,
    frame_end=5,
    protein_atom_count=627,
)

analyzer.run()
analyzer.plot()
# Out:
# ▶ Processing PLacyl...
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/PLacyl/PLacyl_corrected_frame_0.gro -o ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_0.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_0.gro to ../results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_0.gro.2#
#
# GROMACS reminds you: "It's Time to Move On" (F. Black)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/PLacyl/PLacyl_corrected_frame_1.gro -o ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_1.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_1.gro to ../results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_1.gro.2#
#
# GROMACS reminds you: "And I Will Strike Down Upon Thee With Great Vengeance and With Furious Anger Those Who Attempt to Poison and Destroy My Brothers." (Pulp Fiction)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/PLacyl/PLacyl_corrected_frame_2.gro -o ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_2.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_2.gro to ../results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_2.gro.2#
#
# GROMACS reminds you: "Some People Say Not to Worry About the Air" (The Talking Heads)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/PLacyl/PLacyl_corrected_frame_3.gro -o ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_3.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_3.gro to ../results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_3.gro.2#
#
# GROMACS reminds you: "Mathematics is no more computation than typing is literature." (John Allen Paulos)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/PLacyl/PLacyl_corrected_frame_4.gro -o ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_4.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_4.gro to ../results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_4.gro.1#
#
# GROMACS reminds you: "She Says She Can't Go Home Without a Chaperone" (E. Costello)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/PLacyl/PLacyl_corrected_frame_5.gro -o ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_5.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/PLacyl/renumbered_PLacyl_corrected_frame_5.gro to ../results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_5.gro.1#
#
# GROMACS reminds you: "C has the power of assembly language and the convenience of... assembly language." (Dennis Ritchie)
# Done: PLacyl, Frames: 6
#
# ▶ Processing TGacyl...
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGacyl/TGacyl_corrected_frame_0.gro -o ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_0.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_0.gro to ../results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_0.gro.4#
#
# GROMACS reminds you: "Why, how now, Claudio ! Whence Comes this Restraint ?" (Lucio in Measure for measure, Act 1, Scene 4, William Shakespeare)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGacyl/TGacyl_corrected_frame_1.gro -o ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_1.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_1.gro to ../results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_1.gro.4#
#
# GROMACS reminds you: "Calling a system 'non-linear' is like calling all wild animals 'non-elephants'." (Stan Ulam)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGacyl/TGacyl_corrected_frame_2.gro -o ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_2.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_2.gro to ../results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_2.gro.4#
#
# GROMACS reminds you: "You Dirty Switch, You're On Again" (The Breeders)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGacyl/TGacyl_corrected_frame_3.gro -o ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_3.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_3.gro to ../results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_3.gro.4#
#
# GROMACS reminds you: "In a Deep Deep Well" (Nick Cave)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGacyl/TGacyl_corrected_frame_4.gro -o ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_4.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_4.gro to ../results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_4.gro.2#
#
# GROMACS reminds you: "Bum Stikkie Di Bum Stikkie Di Bum Stikkie Di Bum" (R. Slijngaard)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGacyl/TGacyl_corrected_frame_5.gro -o ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_5.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGacyl/renumbered_TGacyl_corrected_frame_5.gro to ../results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_5.gro.2#
#
# GROMACS reminds you: "If a rat is a good model for your emotional life, you're in big trouble." (Robert Sapolsky)
# Done: TGacyl, Frames: 6
#
# ▶ Processing TGglyc...
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGglyc/TGglyc_corrected_frame_0.gro -o ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_0.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_0.gro to ../results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_0.gro.4#
#
# GROMACS reminds you: "You still have to climb to the shoulders of the giants" (Vedran Miletic)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGglyc/TGglyc_corrected_frame_1.gro -o ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_1.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_1.gro to ../results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_1.gro.4#
#
# GROMACS reminds you: "That Was Really Cool" (Butthead)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGglyc/TGglyc_corrected_frame_2.gro -o ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_2.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_2.gro to ../results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_2.gro.4#
#
# GROMACS reminds you: "Check Your Input" (D. Van Der Spoel)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGglyc/TGglyc_corrected_frame_3.gro -o ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_3.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_3.gro to ../results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_3.gro.4#
#
# GROMACS reminds you: "I couldn't give a shit about ribosomes." (Björn Forsberg, presenting his thesis, including two papers on ribosomes)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGglyc/TGglyc_corrected_frame_4.gro -o ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_4.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_4.gro to ../results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_4.gro.2#
#
# GROMACS reminds you: "Unfortunately, "simulation" has become increasingly misused to mean nothing more than "calculation"" (Bill Jorgensen)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect/notebooks
# Command line:
#   gmx genconf -f ../results_radius/TGglyc/TGglyc_corrected_frame_5.gro -o ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_5.gro -renumber
#
#
# Back Off! I just backed up ../results_radius/TGglyc/renumbered_TGglyc_corrected_frame_5.gro to ../results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_5.gro.2#
#
# GROMACS reminds you: "Remember, being healthy is basically dying as slowly as possible." (Ricky Gervais)
# Done: TGglyc, Frames: 6

# %% [markdown]
# ### Option 2: Script-Style Execution via python -m (also works in notebooks)

# %%
# %cd ..
# !python -m packing_defect.run_radius \
  --input results \
  --output results_radius \
  --lipids PLacyl TGacyl TGglyc \
  --start 0 --end 5 --protein-count 627
# Out:
# /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Processing PLacyl...
# Renumbering PLacyl files...
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/PLacyl/PLacyl_corrected_frame_0.gro -o results_radius/PLacyl/renumbered_PLacyl_corrected_frame_0.gro -renumber
#
#
# Back Off! I just backed up results_radius/PLacyl/renumbered_PLacyl_corrected_frame_0.gro to results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_0.gro.3#
#
# GROMACS reminds you: "There is nothing new to be discovered in physics now. All that remains is more and more precise measurement." (Lord Kelvin, 1900)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/PLacyl/PLacyl_corrected_frame_1.gro -o results_radius/PLacyl/renumbered_PLacyl_corrected_frame_1.gro -renumber
#
#
# Back Off! I just backed up results_radius/PLacyl/renumbered_PLacyl_corrected_frame_1.gro to results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_1.gro.3#
#
# GROMACS reminds you: "Hangout In the Suburbs If You've Got the Guts" (Urban Dance Squad)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/PLacyl/PLacyl_corrected_frame_2.gro -o results_radius/PLacyl/renumbered_PLacyl_corrected_frame_2.gro -renumber
#
#
# Back Off! I just backed up results_radius/PLacyl/renumbered_PLacyl_corrected_frame_2.gro to results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_2.gro.3#
#
# GROMACS reminds you: "I Was Born to Have Adventure" (F. Zappa)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/PLacyl/PLacyl_corrected_frame_3.gro -o results_radius/PLacyl/renumbered_PLacyl_corrected_frame_3.gro -renumber
#
#
# Back Off! I just backed up results_radius/PLacyl/renumbered_PLacyl_corrected_frame_3.gro to results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_3.gro.3#
#
# GROMACS reminds you: "History has expired" (PubMed Central)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/PLacyl/PLacyl_corrected_frame_4.gro -o results_radius/PLacyl/renumbered_PLacyl_corrected_frame_4.gro -renumber
#
#
# Back Off! I just backed up results_radius/PLacyl/renumbered_PLacyl_corrected_frame_4.gro to results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_4.gro.2#
#
# GROMACS reminds you: "The most exciting phrase to hear in science, the one that heralds new discoveries, is not "Eureka" but "That's funny..."." (Isaac Asimov)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/PLacyl/PLacyl_corrected_frame_5.gro -o results_radius/PLacyl/renumbered_PLacyl_corrected_frame_5.gro -renumber
#
#
# Back Off! I just backed up results_radius/PLacyl/renumbered_PLacyl_corrected_frame_5.gro to results_radius/PLacyl/#renumbered_PLacyl_corrected_frame_5.gro.2#
#
# GROMACS reminds you: "Is This the Right Room for an Argument ?" (Monty Python)
#
# Completed processing for PLacyl.
# Processing TGacyl...
# Renumbering TGacyl files...
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGacyl/TGacyl_corrected_frame_0.gro -o results_radius/TGacyl/renumbered_TGacyl_corrected_frame_0.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGacyl/renumbered_TGacyl_corrected_frame_0.gro to results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_0.gro.5#
#
# GROMACS reminds you: "I wanted to make a clever chemistry joke, but the best ones Argon." (39.948)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGacyl/TGacyl_corrected_frame_1.gro -o results_radius/TGacyl/renumbered_TGacyl_corrected_frame_1.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGacyl/renumbered_TGacyl_corrected_frame_1.gro to results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_1.gro.5#
#
# GROMACS reminds you: "I Quit My Job Blowing Leaves" (Beck)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGacyl/TGacyl_corrected_frame_2.gro -o results_radius/TGacyl/renumbered_TGacyl_corrected_frame_2.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGacyl/renumbered_TGacyl_corrected_frame_2.gro to results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_2.gro.5#
#
# GROMACS reminds you: "Like other defaulters, I like to lay half the blame on ill-fortune and adverse circumstances" (Mr. Rochester in Jane Eyre by Charlotte Bronte)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGacyl/TGacyl_corrected_frame_3.gro -o results_radius/TGacyl/renumbered_TGacyl_corrected_frame_3.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGacyl/renumbered_TGacyl_corrected_frame_3.gro to results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_3.gro.5#
#
# GROMACS reminds you: "If you want to destroy my sweater, hold this thread as I walk away." (Weezer)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGacyl/TGacyl_corrected_frame_4.gro -o results_radius/TGacyl/renumbered_TGacyl_corrected_frame_4.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGacyl/renumbered_TGacyl_corrected_frame_4.gro to results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_4.gro.3#
#
# GROMACS reminds you: "(That makes 100 errors; please try again.)" (TeX)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGacyl/TGacyl_corrected_frame_5.gro -o results_radius/TGacyl/renumbered_TGacyl_corrected_frame_5.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGacyl/renumbered_TGacyl_corrected_frame_5.gro to results_radius/TGacyl/#renumbered_TGacyl_corrected_frame_5.gro.3#
#
# GROMACS reminds you: "It's Calling Me to Break my Bonds, Again..." (Van der Graaf)
#
# Completed processing for TGacyl.
# Processing TGglyc...
# Renumbering TGglyc files...
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGglyc/TGglyc_corrected_frame_0.gro -o results_radius/TGglyc/renumbered_TGglyc_corrected_frame_0.gro -renumber
# Back Off! I just backed up results_radius/TGglyc/renumbered_TGglyc_corrected_frame_0.gro to results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_0.gro.5#
#
# GROMACS reminds you: "The most likely way for the world to be destroyed, most experts agree, is by accident. That's where we come in; we're computer professionals. We cause accidents." (Nathaniel Borenstein)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGglyc/TGglyc_corrected_frame_1.gro -o results_radius/TGglyc/renumbered_TGglyc_corrected_frame_1.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGglyc/renumbered_TGglyc_corrected_frame_1.gro to results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_1.gro.5#
#
# GROMACS reminds you: "Step On the Brakes" (2 Unlimited)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGglyc/TGglyc_corrected_frame_2.gro -o results_radius/TGglyc/renumbered_TGglyc_corrected_frame_2.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGglyc/renumbered_TGglyc_corrected_frame_2.gro to results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_2.gro.5#
#
# GROMACS reminds you: "The scientist is not a person who gives the right answers, he's one who asks the right questions." (Claude Levi-Strauss)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGglyc/TGglyc_corrected_frame_3.gro -o results_radius/TGglyc/renumbered_TGglyc_corrected_frame_3.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGglyc/renumbered_TGglyc_corrected_frame_3.gro to results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_3.gro.5#
#
# GROMACS reminds you: "Your Country Needs YOU" (U.S. Army)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGglyc/TGglyc_corrected_frame_4.gro -o results_radius/TGglyc/renumbered_TGglyc_corrected_frame_4.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGglyc/renumbered_TGglyc_corrected_frame_4.gro to results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_4.gro.3#
#
# GROMACS reminds you: "Documentation is like sex: When it's good it's great, and when it's bad it's better than nothing." (Linus Torvalds)
#
#                       :-) GROMACS - gmx genconf, 2022 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/c/users/jay/desktop/modules/analysis/github/new/packing_defect
# Command line:
#   gmx genconf -f results_radius/TGglyc/TGglyc_corrected_frame_5.gro -o results_radius/TGglyc/renumbered_TGglyc_corrected_frame_5.gro -renumber
#
#
# Back Off! I just backed up results_radius/TGglyc/renumbered_TGglyc_corrected_frame_5.gro to results_radius/TGglyc/#renumbered_TGglyc_corrected_frame_5.gro.3#
#
# GROMACS reminds you: "The physical chemists never use their eyes and are most lamentably lacking in chemical culture. It is essential to cast out from our midst, root and branch, this physical element and return to our laboratories." (Henry Edward Armstrong)
#
# Completed processing for TGglyc.
